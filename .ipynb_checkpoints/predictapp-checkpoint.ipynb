# %%
# load the iris dataset from pycaret repo
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_aa4ca_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aa4ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa4ca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aa4ca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa4ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa4ca_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aa4ca_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_aa4ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aa4ca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aa4ca_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_aa4ca_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
lr=create_model('lr')
# Out:
# <style type="text/css">
# #T_b597f_row10_col0, #T_b597f_row10_col1, #T_b597f_row10_col2, #T_b597f_row10_col3, #T_b597f_row10_col4, #T_b597f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b597f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b597f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b597f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b597f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b597f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b597f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b597f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
# plot residuals of trained model**
plot_model(lr, plot = 'residuals')

# %%
setup(data, target = 'charges', session_id = 123, normalize = True,
           polynomial_features = True, bin_numeric_features= ['age', 'bmi'])
# Out:
# <style type="text/css">
# #T_8763a_row10_col1, #T_8763a_row16_col1, #T_8763a_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8763a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8763a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8763a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8763a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8763a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8763a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8763a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8763a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8763a_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
# ...

# %%
lr2=create_model('lr')
# Out:
# <style type="text/css">
# #T_7ee13_row10_col0, #T_7ee13_row10_col1, #T_7ee13_row10_col2, #T_7ee13_row10_col3, #T_7ee13_row10_col4, #T_7ee13_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7ee13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ee13_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7ee13_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7ee13_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7ee13_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7ee13_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7ee13_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
# plot residuals of trained model**
plot_model(lr2, plot = 'residuals')

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_4e6ea th {
#   text-align: left;
# }
# ...

# %%
best
# Out:
# GradientBoostingRegressor(random_state=123)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7686c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7686c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7686c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7686c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7686c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7686c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7686c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7686c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7686c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7686c_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7686c_row0_col1" class="data row0 col1" >2521.6623</td>
# ...

# %%
final_best=finalize_model(best)

# %%
final_best
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['age', 'bmi', 'children'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('ordinal_encoding',
#                  TransformerWrapper(include=['sex', 'smoker'],
#                                     transfor...
#                 ('polynomial_features',
#                  TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                 ('bin_numeric_features',
#                  TransformerWrapper(include=['age', 'bmi'],
#                                     transformer=KBinsDiscretizer(encode='ordinal',
# ...

# %%
save_model(final_best, 'gradboostregModel')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['age', 'bmi', 'children'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['sex', 'smoker'],
#                                      transfor...
#                  ('polynomial_features',
#                   TransformerWrapper(transformer=PolynomialFeatures(include_bias=False))),
#                  ('bin_numeric_features',
#                   TransformerWrapper(include=['age', 'bmi'],
#                                      transformer=KBinsDiscretizer(encode='ordinal',
# ...

# %%
# %pip install streamlit
# Out:
# ...
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB 7.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/8.4 MB 4.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.4 MB 5.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.4 MB 5.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.4 MB 5.1 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/8.4 MB 5.0 MB/s eta 0:00:02
# ...

# %%
streamlit run app.py
# Out:
#   Cell In[59], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
